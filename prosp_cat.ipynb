# %%
import numpy as np
import matplotlib.pyplot as plt 
from astropy.io import fits

# %%
def latex():
    plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'Serif',
    'figure.dpi': 250
    })

# %%
prosp_cat_filepath = '/home/marcia/prospector/prosp_properties_GOODSS.fits'
hdul = fits.open(prosp_cat_filepath)
hdul.info()
# Out:
# Filename: /home/marcia/prospector/prosp_properties_GOODSS.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    120   35442R x 56C   [K, K, D, K, D, 8A, 8A, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D]

# %%
primary_HDU = hdul[0]
primary_HDU.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T

# %%
hdu = hdul[1].header
hdu
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  448 / length of dimension 1
# NAXIS2  =                35442 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   56 / number of table fields
# TTYPE1  = 'ID      '
# TFORM1  = 'K       '
# TTYPE2  = 'Nphot(HST+JWST)'
# TFORM2  = 'K       '
# TTYPE3  = 'red_chi2(HST+JWST)'
# TFORM3  = 'D       '
# TTYPE4  = 'Nphot(JWST)'
# TFORM4  = 'K       '
# TTYPE5  = 'red_chi2(JWST)'
# TFORM5  = 'D       '
# TTYPE6  = 'SN(F277W)'
# TFORM6  = '8A      '
# TTYPE7  = 'SN(F356W)'
# TFORM7  = '8A      '
# TTYPE8  = 'SN(F444W)'
# TFORM8  = 'D       '
# TTYPE9  = 'z       '
# TFORM9  = 'D       '
# TTYPE10 = 'z_elo   '
# TFORM10 = 'D       '
# TTYPE11 = 'z_ehi   '
# TFORM11 = 'D       '
# ...

# %%
objids = hdul[1].data['ID']
z = hdul[1].data['z']
sfr5 = hdul[1].data['SFR5']
sfr10 = hdul[1].data['SFR10']
sfr50 = hdul[1].data['SFR50']
sfr100 = hdul[1].data['SFR100']
sfr2000 = hdul[1].data['SFR2000']
st_mass = hdul[1].data['log(Mstar)']
z
# Out:
# array([3., 3., 3., ..., 9., 9., 9.], dtype='>f8')

# %%
latex()
plt.hist(z, bins=200)
plt.xlabel('$z$')
# Out:
# Text(0.5, 0, '$z$')

# %%
latex()
plt.hist(st_mass, bins=200)
plt.xlabel('$\\log(M_* / M_{\\odot})$')
# Out:
# Text(0.5, 0, '$\\log(M_* / M_{\\odot})$')

# %%
plt.scatter(z, st_mass, s=1, alpha=0.1)

# %%
objids[(z > 8.5) & (st_mass < 6.3)]
# Out:
# array([262613], dtype='>i8')

# %%
plt.hist(sfr10, bins=np.linspace(0, 10, num=200))
 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.998e+03, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.996e+03, 0.000e+00, 0.000e+00, 1.838e+03,
#         0.000e+00, 0.000e+00, 1.745e+03, 0.000e+00, 1.529e+03, 0.000e+00,
#         1.434e+03, 0.000e+00, 1.244e+03, 1.153e+03, 0.000e+00, 1.033e+03,
#         9.630e+02, 8.210e+02, 7.680e+02, 6.740e+02, 6.650e+02, 6.180e+02,
#         5.140e+02, 4.840e+02, 9.180e+02, 4.110e+02, 7.430e+02, 6.630e+02,
#         3.080e+02, 5.360e+02, 4.490e+02, 6.270e+02, 4.250e+02, 5.090e+02,
#         3.170e+02, 4.000e+02, 3.650e+02, 4.660e+02, 2.880e+02, 3.490e+02,
#         3.030e+02, 3.530e+02, 2.800e+02, 2.830e+02, 2.320e+02, 2.360e+02,
#         2.400e+02, 2.270e+02, 2.040e+02, 2.090e+02, 2.060e+02, 1.620e+02,
#         2.160e+02, 1.670e+02, 1.600e+02, 1.410e+02, 1.390e+02, 1.530e+02,
# ...

# %%
nonzero = (sfr10 > 0) & (sfr100 > 0)
plt.hist(sfr10[nonzero] / sfr100[nonzero], bins=100)
# Out:
# (array([7.430e+02, 7.830e+02, 1.314e+03, 2.279e+03, 2.712e+03, 2.190e+03,
#         2.683e+03, 1.782e+03, 1.606e+03, 1.634e+03, 1.034e+03, 1.297e+03,
#         8.960e+02, 1.140e+03, 9.790e+02, 7.960e+02, 7.580e+02, 7.370e+02,
#         5.810e+02, 9.170e+02, 3.180e+02, 5.080e+02, 4.530e+02, 5.250e+02,
#         4.420e+02, 2.940e+02, 5.580e+02, 2.560e+02, 3.050e+02, 3.590e+02,
#         1.550e+02, 2.510e+02, 1.460e+02, 4.180e+02, 1.890e+02, 2.000e+02,
#         1.970e+02, 1.550e+02, 1.380e+02, 3.130e+02, 5.400e+01, 1.140e+02,
#         1.120e+02, 1.570e+02, 1.210e+02, 6.900e+01, 1.930e+02, 5.300e+01,
#         8.100e+01, 9.400e+01, 3.500e+01, 7.600e+01, 2.900e+01, 1.440e+02,
#         4.700e+01, 4.800e+01, 7.300e+01, 4.800e+01, 3.300e+01, 1.420e+02,
#         2.100e+01, 4.500e+01, 3.700e+01, 5.400e+01, 4.700e+01, 2.700e+01,
#         7.200e+01, 1.200e+01, 1.300e+01, 1.400e+01, 2.000e+00, 6.000e+00,
#         0.000e+00, 3.400e+01, 0.000e+00, 3.000e+00, 9.000e+00, 0.000e+00,
# ...

# %%
burst = sfr10[nonzero] / sfr100[nonzero]

plt.scatter(z[nonzero], burst, s=1, alpha=0.1)

# %%
burst = sfr10[nonzero] / sfr100[nonzero]

plt.scatter(st_mass[nonzero], burst, s=1, alpha=0.1)
# plt.yscale('log')
